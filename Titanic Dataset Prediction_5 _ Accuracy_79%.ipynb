# %%
import pandas as pd
import numpy as np
import random
from sklearn import preprocessing, model_selection, neighbors
from sklearn.svm import LinearSVC, SVC

# %%
df_train=pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')

# %%
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dftrain = df_train.copy(deep=True)
dftest = df_test.copy(deep=True)

# %%
dftrain['Age'].isnull().sum()
# Out:
# 177

# %%
dftest.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
dftrain['Age'].fillna(dftrain['Age'].mean(),inplace=True)
dftest['Age'].fillna(dftest['Age'].mean(),inplace=True)

# %%
lis=dftrain['Embarked'].value_counts().to_dict()
lis[np.nan]=lis['S']
for i in lis:
    lis[i]=lis[i]/dftrain.shape[0]
lis
dftrain['Embarked']=dftrain['Embarked'].map(lis)


liss=dftest['Embarked'].value_counts().to_dict()
liss[np.nan]=liss['S']
for j in liss:
    liss[j]=liss[j]/dftest.shape[0]
liss
dftest['Embarked']=dftest['Embarked'].map(liss)

# %%
lis2={'male':1,'female':0}
dftrain['Sex']=dftrain['Sex'].map(lis2)
dftest['Sex']=dftest['Sex'].map(lis2)

# %%
dftrain.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
dftrain
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.000000      1
# 2                               Heikkinen, Miss. Laina    0  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.000000      1
# 4                             Allen, Mr. William Henry    1  35.000000      0
# ...

# %%
features = ["Pclass", "Sex", "SibSp", "Parch", "Embarked", "Age"]

# %%
# X=np.array(dftrain[features])
# Y=np.array(dftrain['Survived'])
# Z=np.array(dftest[features])
# # X_train,X_test,Y_train,Y_test=model_selection.train_test_split(X,Y,test_size=0.2)
# clf=neighbors.KNeighborsClassifier(n_neighbors=3)
# clf.fit(X,Y)
# predictions=clf.predict(Z)
# out=pd.DataFrame({'PassengerId':dftest.PassengerId,'Survived':predictions})
# out.to_csv('Titanic-5.csv',index=False)

# %%
dftrainsvc=df_train.copy(deep=True)
dftestsvc=df_test.copy(deep=True)

# %%
dftrainsvc['Age'].fillna(dftrainsvc['Age'].mean(),inplace=True)
dftestsvc['Age'].fillna(dftestsvc['Age'].mean(),inplace=True)

# %%
def ages(age):
    if age<=15:
        return 'child'
    elif age>15 and age<55:
        return 'adult'
    elif age>5:
        return 'old'

# %%
dftrainsvc['Age']=dftrainsvc['Age'].map(lambda age:ages(age))
dftestsvc['Age']=dftestsvc['Age'].map(lambda age:ages(age))

# %%
dftrainsvc
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  adult      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  adult      1
# 2                               Heikkinen, Miss. Laina  female  adult      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  adult      1
# 4                             Allen, Mr. William Henry    male  adult      0
# ...

# %%
ysvc=dftrainsvc['Survived']
Xsvc= pd.get_dummies(dftrainsvc[features])
print(Xsvc)
X_testsvc = pd.get_dummies(dftestsvc[features])
print(X_testsvc)
# Out:
#      Pclass  SibSp  Parch  Sex_female  Sex_male  Embarked_C  Embarked_Q  \
# 0         3      1      0           0         1           0           0
# 1         1      1      0           1         0           1           0
# 2         3      0      0           1         0           0           0
# 3         1      1      0           1         0           0           0
# 4         3      0      0           0         1           0           0
# ..      ...    ...    ...         ...       ...         ...         ...
# 886       2      0      0           0         1           0           0
# 887       1      0      0           1         0           0           0
# 888       3      1      2           1         0           0           0
# 889       1      0      0           0         1           1           0
# 890       3      0      0           0         1           0           1
#
#      Embarked_S  Age_adult  Age_child  Age_old
# 0             1          1          0        0
# ...

# %%
model = SVC()
model.fit(Xsvc, ysvc)
predictionsvc = model.predict(X_testsvc)


output = pd.DataFrame({'PassengerId': dftestsvc.PassengerId, 'Survived': predictionsvc})
output.to_csv('Titanic-svc.csv', index=False)

# %%
# Xsvc=np.array(dftrainsvc[features])
# Ysvc=np.array(dftrainsvc['Survived'])
# Zsvc=np.array(dftestsvc[features])
# # X_train,X_test,Y_train,Y_test=model_selection.train_test_split(X,Y,test_size=0.2)
# clf=SVC()
# clf.fit(Xsvc,Ysvc)
# predictionsvc=clf.predict(Zsvc)
# outsvc=pd.DataFrame({'PassengerId':dftest.PassengerId,'Survived':predictionsvc})
# outsvc.to_csv('Titanic-svc.csv',index=False)
